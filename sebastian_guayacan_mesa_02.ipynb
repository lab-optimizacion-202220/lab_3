# %% [markdown]
# # PRIMER PUNTO

# %%
def capicula (num):
    ans = 0
    rev = str (num)[::-1]
    if (rev == str(num)):
        ans = 1
    return ans

# %%
capicula(212)
# Out:
# 1

# %%
capicula(2332)
# Out:
# 1

# %%
capicula(12345678987654321)
# Out:
# 1

# %%
capicula (555555)
# Out:
# 1

# %%
import time
def capiculas (num):
    ans = 0
    aux = 0
    start = time.time()
    for i in range(num+1) :
        if capicula(aux) == 1 and aux >10:
            ans = ans + 1
        
        aux  = aux + 1
    end = time.time()
    print (f"Tiempo: {end - start}")
    return ans

# %%
capiculas (10000000)
# Out:
# Tiempo: 17.99470615386963
# 10989

# %% [markdown]
# # SEGUNDO PUNTO

# %%
def ordenar_listas (A,B):
    ans = A + B
    ans.sort()
    return ans

# %%
ordenar_listas([1, 3 , 5,7,9 ], [2,4,6.5,8,10])
# Out:
# [1, 2, 3, 4, 5, 6.5, 7, 8, 9, 10]

# %%
#Un posible error que se puede producir es cuando alguno de los valores introducidos en la lista no es un  número.

# %% [markdown]
# # TERCER PUNTO

# %%
from matplotlib import pyplot, pylab, mlab
from pylab import *
import numpy as np
x = np.linspace(-2, 2, 256,endpoint=True)
S =  np.sin(1/x)
plot(x,S)
show()

# %%
x1 = np.linspace(-2, 2, 256,endpoint=True)
x2 = np.linspace(2, 6, 256,endpoint=True)
y1 = x1**2
y2 = 15-x2**2
plot(x1,y1, color = "green")
plot(x2,y2, color = "green")
show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-1, 1, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array(X+Y**2)
Z = zs.reshape(X.shape)
ax.plot_surface(X, Y, Z)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-5, 5, 0.05)
X, Y = np.meshgrid(x, y)
zs = np.array(Y*np.cos(X))
Z = zs.reshape(X.shape)
ax.plot_surface(X, Y, Z)
plt.show()

# %% [markdown]
# # CUARTO PUNTO

# %%
import sympy as sym
sym.init_printing()
a,b,c = sym.symbols('a,b,c')
#sistema de acuaciones planteado:
f = sym.Eq(2*a + 3*b + 4*c, 80)
g = sym.Eq(2*a + 2*b + 3*c, 60)

sol = sym.solve([f,g],(a,b,c))
print (f"Solución al sistema {sol} ")
# Out:
# Solución al sistema {a: 10 - c/2, b: 20 - c}

# %%
c =np.arange(0,20,1)
a  = 10 - c/2
b = 20-c
c,c= np.meshgrid(c,c)
fig = plt.figure( )
ax = plt.axes(projection='3d')
ax.plot_surface(a,b, c)
plt.show()

# %%
# fabhjbhj

# %% [markdown]
# # QUINTO PUNTO

# %%
#sistema de ecuaciones planteado para el spline cuadrático:
# y = a + b*x + c*x²
sym.init_printing()
a,b,c = sym.symbols('a,b,c')
f = sym.Eq(a + b + c, 3)
g = sym.Eq(a + 2*b + 4*c, 4)
h = sym.Eq(a + 3*b + 6*c, 7)

sol = sym.solve([f,g,h],(a,b,c))
print (f"Solución al sistema {sol} ")
# Out:
# Solución al sistema {a: -2, b: 7, c: -2}

# %% [markdown]
# # SEXTO PUNTO

# %%
A = np.array([[1,-3],[3,-5]])
B = np.array([[3,-1,4],[-1,0,1],[4,1,2]])
C = np.array([[2,-2,0],[1,-1,0],[1,1,0]])
D = np.array([[2,4],[3,6]])

# %%
#matriz A:
vpA,vcpA = linalg.eig(A)
print (f" valores propios: {vpA} \n vectores propios: {vcpA}")
# Out:
#  valores propios: [-2. -2.]
#  vectores propios: [[0.70710678 0.70710678]
#  [0.70710678 0.70710678]]

# %%
#matriz B:
vpB,vcpB = linalg.eig(B)
print (f" valores propios: {vpB} \n vectores propios: {vcpB}")
# Out:
#  valores propios: [ 6.53235748 -2.37152077  0.83916329]
#  vectores propios: [[-0.75122217  0.57242079 -0.32863307]
#  [ 0.01397976  0.51157837  0.85912289]
#  [-0.65990137 -0.64079795  0.39231132]]

# %%
#matriz C:
vpC,vcpC = linalg.eig(C)
print (f" valores propios: {vpC} \n vectores propios: {vcpC}")
# Out:
#  valores propios: [0. 0. 1.]
#  vectores propios: [[ 0.00000000e+000 -1.50312627e-292 -5.34522484e-001]
#  [ 0.00000000e+000 -1.50312627e-292 -2.67261242e-001]
#  [ 1.00000000e+000  1.00000000e+000 -8.01783726e-001]]

# %%
#matriz D:
vpD,vcpD = linalg.eig(D)
print (f" valores propios: {vpD} \n vectores propios: {vcpD}")
# Out:
#  valores propios: [0. 8.]
#  vectores propios: [[-0.89442719 -0.5547002 ]
#  [ 0.4472136  -0.83205029]]
